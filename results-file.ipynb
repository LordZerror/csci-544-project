# %%
gemini_triplets = [
    [
      "sensor data",
      "measured_by",
      "sensors"
    ],
    [
      "sensors",
      "component_of",
      "monitoring"
    ],
    [
      "biodiversity monitoring",
      "involves",
      "sending observers"
    ],
    [
      "traditional surveys",
      "to_meet",
      "global conservation"
    ],
    [
      "human observers",
      "lead_to",
      "negative ecological impacts"
    ],
    [
      "adaptive management",
      "of",
      "conservation projects"
    ],
    [
      "conservation",
      "produces",
      "conservation outcomes"
    ],
    [
      "sensor data",
      "analyzed_by",
      "analysts"
    ],
    [
      "data",
      "flows_to",
      "base stations"
    ],
    [
      "base stations",
      "transmits_via",
      "internet"
    ],
    [
      "base stations",
      "transmits_via",
      "satellite"
    ],
    [
      "base stations",
      "transmits_via",
      "microwave"
    ],
    [
      "cellular networks",
      "transmits_via",
      "base stations"
    ],
    [
      "data",
      "stored_at",
      "data center"
    ],
    [
      "data center",
      "uses",
      "Spark"
    ],
    [
      "analysts",
      "uses",
      "exploration tools"
    ],
    [
      "exploration tools",
      "visualizes",
      "data"
    ],
    [
      "data clustering",
      "used_for",
      "t-SNE"
    ],
    [
      "DL algorithms",
      "applied_to",
      "biodiversity monitoring"
    ],
    [
      "models",
      "trained_for",
      "species"
    ],
    [
      "deep learning",
      "component_of",
      "machine learning"
    ],
    [
      "AI algorithm",
      "application_of",
      "visual object recognition"
    ],
    [
      "AI algorithm",
      "application_of",
      "speech recognition"
    ],
    [
      "AI algorithm",
      "application_of",
      "genomics"
    ],
    [
      "Deep Learning",
      "subfield_of",
      "machine learning"
    ],
    [
      "DL",
      "grew_out_of",
      "representation learning"
    ],
    [
      "DL",
      "grew_out_of",
      "neural networks"
    ],
    [
      "DL",
      "grew_out_of",
      "computational neuroscience"
    ],
    [
      "sensor networks",
      "produces",
      "petabytes"
    ],
    [
      "sensor networks",
      "produces",
      "exabytes"
    ],
    [
      "Queensland",
      "part_of",
      "Australia"
    ],
    [
      "brown tree snake",
      "native_to",
      "Papua New Guinea"
    ],
    [
      "summer of 2012",
      "precedes",
      "summer of 2014"
    ],
     [
      "CNNs",
      "type_of",
      "neural networks"
    ],
    [
      "DNNs",
      "type_of",
      "neural networks"
    ],
    [
      "species",
      "part_of",
      "biodiversity"
    ],
     [
      "data",
      "part_of",
      "datasets"
    ]
  ]

# %%
gemini_rag_triplets = [
        ["Ecosystem services", "are", "the contribution of nature to human well-being"]
        ,["sensor networks", "used_for", "conservation"]
        ,["analysts", "analyzed_by", "sensor data"]
        ,["sensor data", "produced_by", "sensors"]
        ,["sensors", "include", "microphones"]
        ,["sensors", "include", "cameras"]
        ,["cameras", "type_of", "visual"]
        ,["cameras", "type_of", "thermal"]
        ,["cameras", "type_of", "hyperspectral"]
        ,["data", "flows_to", "data center"]
        ,["data", "analyzed_by", "algorithms"]
        ,["Artificial Intelligence", "used_for", "biodiversity monitoring"]
        , ["machine learning", "used_for", "biodiversity monitoring"]
        , ["deep learning", "used_for", "biodiversity monitoring"]
        , ["Deep Learning", "subfield_of", "Artificial Intelligence"]
        , ["Deep Learning", "subfield_of", "machine learning"]
        , ["sensor networks", "to_collect", "sensor data"]
        , ["mobile phones", "gather", "sensor data"]
        , ["data", "stored_at", "Amazon Web Services"]
        , ["data", "stored_at", "third-party data centers"]
        , ["satellites", "to_collect", "images"]
        , ["satellites", "to_collect", "data"]
        , ["un-manned aerial vehicles", "to_collect", "images"]
        , ["observers", "to_collect", "data"]
        , ["AI algorithm", "to_collect", "sensor data"]
        , ["audio", "analyzed_by", "spectrograms"]
        , ["brown tree snake", "native_to", "Papua New Guinea"]
        , ["brown tree snake", "introduced_by", "U.S. military"]
        , ["Guam", "part_of", "Micronesia"]
        , ["Puffinus bryani", "is_a", "species"]
        , ["Ashy Storm-petrel", "is_a", "species"]
        , ["Conservation Metrics, Inc.", "developed", "biodiversity monitoring application"]
        , ["data clustering", "used_for", "view and select data samples"]
        , ["data clustering", "example_of", "t-SNE"]
        , ["DL algorithms", "trained_to", "classify events of interest"]
        , ["DL algorithms", "type_of", "CNNs"]
        , ["DL algorithms", "type_of", "DNNs"]
        , ["environmental sensor data", "measured_by", "temperature"]
        , ["global positioning systems", "used_to", "improve wildlife monitoring techniques"]
        , ["technology", "used_to", "improve conservation monitoring"]
        , ["technology", "used_for", "data analysis"]
    ]

# %%
len(gemini_triplets), len(gemini_rag_triplets)
# Out:
# (37, 41)

# %%
llama_triplets = [
    ["Deep Learning", "used_for", "Biodiversity"],
        ["Sensors", "part_of", "Monitoring"],
        ["Monitoring", "improves", "Conservation"],
        ["Data", "analyzed_by", "Analysts"],
        ["Deep Learning", "part_of", "Artificial Intelligence"],
        ["Species", "part_of", "Ecosystems"],
        ["Biodiversity", "involves", "Species"],
        ["Conservation", "produces", "Conservation outcomes"],
        ["Sensors", "produces", "Data"]
]

# %%
llama_rag_triplets = [
    ["Deep Learning", "used_for", "Biodiversity Monitoring"],
        ["Sensor Data", "analyzed_by", "Machine Learning"],
        ["Conservation Metrics, Inc.", "uses", "Deep Learning"],
        ["Biodiversity", "measured_by", "Sensor Networks"],
        ["Ecosystems", "monitored_by", "Cameras"],
        ["David J. Klein", "part_of", "Conservation Metrics, Inc."],
        ["Matthew W. McKown", "part_of", "Conservation Metrics, Inc."],
        ["Bernie R. Tershy", "part_of", "Conservation Metrics, Inc."],
        ["Amazon Web Services", "used_for", "Cloud Computing and Storage"],
        ["Sensor Networks", "used_for", "Wildlife Monitoring"],
        ["Machine Learning", "applied_to", "Conservation"],
        ["Conservation", "aims_to", "Biodiversity"],
        ["Species", "monitored_by", "Sensor Networks"]
]

# %%
len(llama_triplets), len(llama_rag_triplets)
# Out:
# (9, 13)

# %% [markdown]
# ### Gemini RAG Triplets to RDF Format
#
# @prefix ex: <http://example.org/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#
# ex:David_J_Klein ex:affiliated_with ex:Conservation_Metrics_Inc .
# ex:Matthew_W_McKown ex:affiliated_with ex:Conservation_Metrics_Inc .
# ex:Bernie_R_Tershy ex:affiliated_with ex:Conservation_Metrics_Inc .
# ex:Conservation_Metrics_Inc ex:located_in ex:site .
# ex:DL ex:used_by ex:models .
# ex:models ex:monitors ex:species .
# ex:models ex:monitors ex:ecosystems .
# ex:audio ex:component_of ex:sensors .
# ex:cameras ex:component_of ex:sensors .
# ex:natural_systems ex:component_of ex:Ecosystem_services .
# ex:Convention_for_Global_Biodiversity ex:affiliated_with ex:UN .
# ex:conservation ex:produces ex:conservation_outcomes .
# ex:wildlife_monitoring_techniques ex:component_of ex:conservation_measures_program .
# ex:natural_systems ex:component_of ex:natural_systems .
# ex:droughts ex:component_of ex:natural_systems .
# ex:biological_surveys ex:part_of ex:monitoring_programs .
# ex:conservation_actions ex:part_of ex:monitoring_programs .
# ex:conservation_actions ex:measured_by ex:data .
# ex:wildlife_monitoring_techniques ex:improve ex:inference .
# ex:wildlife_monitoring_techniques ex:drive ex:adaptive_management .
# ex:adaptive_management ex:of ex:conservation_projects .
# ex:biodiversity_monitoring ex:involves ex:sending_observers .
# ex:survey_sites ex:to_collect ex:data .
# ex:traditional_surveys ex:to_meet ex:global_conservation .
# ex:human_observers ex:lead_to ex:negative_ecological_impacts .
# ex:sensors ex:component_of ex:monitoring .
# ex:audio ex:part_of ex:sensors .
# ex:cameras ex:part_of ex:sensors .
# ex:gradients ex:part_of ex:sensors .
# ex:visual ex:type_of ex:cameras .
# ex:thermal ex:type_of ex:cameras .
# ex:hyperspectral ex:type_of ex:cameras .
# ex:New_York_City ex:located_in ex:New_York_City .
# ex:technology ex:component_of ex:technology .
# ex:global_positioning_systems ex:component_of ex:technology .
# ex:cellular_networks ex:component_of ex:technology .
# ex:satellites ex:component_of ex:technology .
# ex:airplanes ex:component_of ex:technology .
# ex:un_manned_aerial_vehicles ex:component_of ex:technology .
# ex:DL ex:used_for ex:biodiversity .
# ex:sensor_data ex:measured_by ex:sensors .
# ex:audio ex:part_of ex:datasets .
# ex:image ex:part_of ex:datasets .
# ex:temperature ex:part_of ex:environmental_sensor_data .
# ex:site ex:part_of ex:monitoring_project .
# ex:region ex:part_of ex:monitoring_project .
# ex:cloud_computing_and_storage ex:component_of ex:internet .
# ex:internet ex:depends_on ex:cloud_computing_and_storage .
# ex:mobile_phones ex:used_for ex:gather_sensor_data .
# ex:sensors ex:component_of ex:communication_network .
# ex:data ex:flows_to ex:base_stations .
# ex:base_stations ex:transmits_via ex:internet .
# ex:base_stations ex:transmits_via ex:satellite .
# ex:base_stations ex:transmits_via ex:microwave .
# ex:base_stations ex:transmits_via ex:cellular_networks .
# ex:data ex:stored_at ex:data_center .
# ex:data_center ex:uses ex:Spark .
# ex:Amazon_Web_Services ex:is_a ex:third_party_data_centers .
# ex:DL ex:component_of ex:machine_learning .
# ex:models ex:produced_by ex:labeled_datasets .
# ex:models ex:trained_to ex:classify_events_of_interest .
# ex:data ex:according_to ex:date_ranges .
# ex:data ex:according_to ex:time_of_day .
# ex:data ex:according_to ex:site_location .
# ex:audio_signals ex:frequency_ranges ex:data .
# ex:models ex:used_for ex:species .
# ex:analysts ex:uses ex:exploration_tools .
# ex:sensor_data ex:analyzed_by ex:analysts .
# ex:exploration_tools ex:visualizes ex:data .
# ex:t_SNE ex:used_for ex:data_clustering .
# ex:t_SNE ex:used_for ex:view_and_select_data_samples .
# ex:feature_vector ex:is ex:384_dimensional .
# ex:models ex:classify ex:species .
# ex:models ex:classify ex:events .
# ex:keyboard_shortcuts ex:uses ex:panels .
# ex:spectrograms ex:represents ex:audio .
# ex:Artificial_Intelligence ex:abbreviation_of ex:AI .
# ex:machine_learning ex:component_of ex:Artificial_Intelligence .
# ex:AI ex:uses ex:data .
# ex:machine_learning ex:uses ex:data .
# ex:sensor_networks ex:produces ex:petabytes .
# ex:sensor_networks ex:produces ex:exabytes .
# ex:analysts ex:uses ex:keyboard_shortcuts .
# ex:Deep_Learning ex:abbreviation_of ex:DL .
# ex:DL ex:subfield_of ex:machine_learning .
# ex:DL ex:grew_out_of ex:representation_learning .
# ex:DL ex:grew_out_of ex:neural_networks .
# ex:DL ex:grew_out_of ex:computational_neuroscience .
# ex:edges ex:component_of ex:image .
# ex:gradients ex:component_of ex:image .
# ex:corners ex:component_of ex:image .
# ex:textures ex:component_of ex:image .
# ex:visual_object_recognition ex:application_of ex:DL .
# ex:speech_recognition ex:application_of ex:DL .
# ex:genomics ex:application_of ex:DL .
# ex:visual_object_recognition ex:application_of ex:AI_algorithm .
# ex:speech_recognition ex:application_of ex:AI_algorithm .
# ex:genomics ex:application_of ex:AI_algorithm .
# ex:unconstrained_image_recognition ex:example_of ex:difficult_problems .
# ex:DL_algorithm ex:is_a ex:ML_algorithm .
# ex:biodiversity_monitoring_application ex:candidate_for ex:DL .
# ex:CNNs ex:part_of ex:DL .
# ex:DNNs ex:part_of ex:DL .
# ex:DL_algorithms ex:applied_to ex:biodiversity_monitoring .
# ex:models ex:trained_for ex:species .
# ex:species ex:related_to ex:species .
# ex:audio ex:component_of ex:sensors .
# ex:image ex:component_of ex:sensors .
# ex:International_Union_for_Conservation ex:part_of ex:RedList .
# ex:Channel_Islands_National_Park ex:located_in ex:Anacapa_Island .
# ex:Ashy_Storm_petrel ex:scientific_name ex:Puffinus .
# ex:Bryans_Shearwater ex:scientific_name ex:Puffinus .
# ex:Bryans_Shearwater ex:member_of ex:Puffinus .
# ex:Queensland ex:located_in ex:Australia .
# ex:Great_Barrier_Reef_Marine_Park ex:located_in ex:Australia .
# ex:California_Coastal_National_Monument ex:located_in ex:US_Geological_Survey .
# ex:Island_of_Guam ex:located_in ex:Guam .
# ex:brown_tree_snake ex:scientific_name ex:Boiga_irregularis .
# ex:brown_tree_snake ex:native_to ex:Papua_New_Guinea .
# ex:brown_tree_snake ex:introduced_by ex:US_military .
# ex:US_Geological_Survey ex:located_in ex:Guam .
# ex:summer_of_2012 ex:precedes ex:summer_of_2014 .

# %% [markdown]
# ### Llama RAG Triplets to RDF Format
#
# @prefix ex: <http://example.org/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#
# ex:Deep_Learning ex:used_for ex:Biodiversity_Monitoring .
# ex:Sensor_Data ex:analyzed_by ex:Machine_Learning .
# ex:Conservation_Metrics_Inc ex:uses ex:Deep_Learning .
# ex:Biodiversity ex:measured_by ex:Sensor_Networks .
# ex:Ecosystems ex:monitored_by ex:Cameras .
# ex:David_J_Klein ex:part_of ex:Conservation_Metrics_Inc .
# ex:Matthew_W_McKown ex:part_of ex:Conservation_Metrics_Inc .
# ex:Bernie_R_Tershy ex:part_of ex:Conservation_Metrics_Inc .
# ex:Amazon_Web_Services ex:used_for ex:Cloud_Computing_and_Storage .
# ex:Sensor_Networks ex:used_for ex:Wildlife_Monitoring .
# ex:Machine_Learning ex:applied_to ex:Conservation .
# ex:Conservation ex:aims_to ex:Biodiversity .
# ex:Species ex:monitored_by ex:Sensor_Networks .
